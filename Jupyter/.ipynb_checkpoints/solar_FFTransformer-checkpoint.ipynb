# %%
# !pwd
# Out:
# /home/taokj/Net/solar_tkj_from_patchTST/Jupyter

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x_pred = np.load('../results/test_solar_1_FFTransformer_custom_ftMS_sl96_ll48_pl96_dm512_nh8_el3_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0/pred.npy',mmap_mode = 'r')
x_true = np.load('../results/test_solar_1_FFTransformer_custom_ftMS_sl96_ll48_pl96_dm512_nh8_el3_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0/true.npy',mmap_mode = 'r')

# %%
x_pred[:,:,-1].shape
# Out:
# (10272, 96)

# %%
df_pred = pd.DataFrame(x_pred[:,:,-1])
df_pred
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.247456  0.236034  0.257932  0.273796  0.223885  0.148072  0.254476
# 1      0.184808  0.135255  0.207502  0.170715  0.215592  0.143297  0.184731
# 2      0.190342  0.158853  0.213335  0.226215  0.190005  0.146437  0.155479
# 3      0.177296  0.156486  0.201388  0.146797  0.140407  0.127504  0.203975
# 4      0.182843  0.133943  0.187483  0.178386  0.141293  0.143217  0.177319
# ...         ...       ...       ...       ...       ...       ...       ...
# 10267 -0.017333  0.031583  0.021340  0.062924  0.022287  0.056361  0.012061
# 10268 -0.000251  0.003969  0.016820  0.002187  0.028633  0.017694  0.057931
# 10269 -0.011172  0.033733 -0.019872  0.027320 -0.009215  0.041141  0.030034
# 10270  0.000844  0.016219 -0.006429  0.009009  0.018188  0.022707  0.021837
# 10271 -0.009701  0.003466 -0.025104  0.029716  0.033640  0.061187  0.002131
#
# ...

# %%
df_true = pd.DataFrame(x_true[:,:,-1])
df_true
# Out:
#                  0             1             2             3             4   \
# 0      5.466599e-03  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# 1      1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# 2      1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# 3      1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# 4      1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# ...             ...           ...           ...           ...           ...
# 10267  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# 10268  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# 10269  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# 10270  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
# 10271  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08  1.849155e-08
#
# ...

# %%
def visual(true, preds=None, name='./pic/test.pdf'):
    """
    Results visualization
    """
    plt.figure()
    plt.plot(true, label='GroundTruth', linewidth=2)
    if preds is not None:
        plt.plot(preds, label='Prediction', linewidth=2)
    plt.legend()
    # plt.savefig(name, bbox_inches='tight')
    plt.show()

# %%
visual(x_true[0,:,-1], x_pred[0,:,-1])

# %%
visual(x_true[96,:,-1], x_pred[96,:,-1])
